# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a040-sandeep/SCSVMV_LABS/blob/main/DV_LAB/experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program 1: Line Plot

# %% [markdown]
# # Program 1: Line Plot

# %%
x <- seq(0, 10, length.out = 100)
y <- sin(x)
plot(x, y, type = 'l', col = 'blue', main = 'Line Plot', xlab = 'X-axis', ylab = 'Y-axis')
# Out:
# Plot with title “Line Plot”

# %% [markdown]
# # Program 2: Bar Chart

# %%
# Program 2: Bar Chart

# %% [markdown]
# # Program 3: Scatter Plot

# %%
categories <- c('A', 'B', 'C', 'D', 'E')
values <- c(23, 45, 56, 78, 32)
barplot(values, names.arg = categories, col = 'steelblue', main = 'Bar Chart')
# Out:
# Plot with title “Bar Chart”

# %% [markdown]
# # Program 4: Pie Chart

# %%
# Program 3: Scatter Plot

# %% [markdown]
# # Program 5: R Line Plot

# %%
x <- seq(0, 10, length.out = 100)
y <- sin(x)
plot(x, y, type = "l", col = "blue", main = "Line Plot", xlab = "X-axis", ylab = "Y-axis")
# Out:
# Plot with title “Line Plot”

# %% [markdown]
# # Program 6: R Bar Chart

# %%
categories <- c('A', 'B', 'C', 'D', 'E')
values <- c(23, 45, 56, 78, 32)
barplot(values, names.arg = categories, col = "steelblue", main = "Bar Chart")
# Out:
# Plot with title “Bar Chart”

# %% [markdown]
# # Program 7: R Scatter Plot

# %%
set.seed(42)
x <- runif(50)
y <- x + rnorm(50, 0, 0.1)
plot(x, y, pch = 19, col = "darkred", main = "Scatter Plot")
# Out:
# Plot with title “Scatter Plot”

# %% [markdown]
# # Program 8: R Pie Chart

# %%
slices <- c(45, 30, 15, 10)
lbls <- c("Python", "Java", "C++", "Ruby")
pie(slices, labels = lbls, main = "Pie Chart", col = terrain.colors(4))
# Out:
# Plot with title “Pie Chart”

# %% [markdown]
# # Program 5: Histogram

# %%
data <- rnorm(100)
hist(data, col='skyblue', border='white', main='Histogram', xlab='Values')
# Out:
# Plot with title “Histogram”

# %% [markdown]
# # Program 6: Box Plot

# %%
boxplot(mpg ~ cyl, data = mtcars, main='Box Plot (MPG by Cyl)', col=c('orange', 'green', 'blue'))
# Out:
# Plot with title “Box Plot (MPG by Cyl)”

# %% [markdown]
# # Program 7: Correlation Heatmap

# %%
res <- cor(mtcars[,1:6])
heatmap(res, main='Correlation Heatmap', col=cm.colors(256))
# Out:
# Plot with title “Correlation Heatmap”

# %% [markdown]
# # Program 8: Density Plot

# %%
d <- density(mtcars$mpg)
plot(d, main='Density Plot of MPG')
polygon(d, col='purple', border='black')
# Out:
# Plot with title “Density Plot of MPG”

# %% [markdown]
# # Program 11: Correlation Heatmap

# %%
res <- cor(mtcars[,1:6])
heatmap(res, main="Correlation Heatmap", col=cm.colors(256))
# Out:
# Plot with title “Correlation Heatmap”

# %% [markdown]
# # Program 12: Density Plot

# %%
d <- density(mtcars$mpg)
plot(d, main="Density Plot of MPG")
polygon(d, col="purple", border="black")
# Out:
# Plot with title “Density Plot of MPG”

# %% [markdown]
# # Program 9: Histogram (Distribution)

# %%
data <- rnorm(100)
hist(data, col="skyblue", border="white", main="Histogram Example", xlab="Value")
# Out:
# Plot with title “Histogram Example”

# %% [markdown]
# # Program 10: Box Plot (Outlier Analysis)

# %%
boxplot(mpg ~ cyl, data = mtcars, main="Boxplot: MPG vs Cylinders", col=c("gold", "coral", "steelblue"), xlab="Cylinders", ylab="MPG")
# Out:
# Plot with title “Boxplot: MPG vs Cylinders”

# %% [markdown]
# # Program 11: Correlation Heatmap

# %%
res <- cor(mtcars)
image(res, main="Correlation Matrix Heatmap", axes=FALSE)
axis(1, at=seq(0, 1, length.out=ncol(mtcars)), labels=colnames(mtcars), las=2)
axis(2, at=seq(0, 1, length.out=ncol(mtcars)), labels=colnames(mtcars), las=2)
# Out:
# Plot with title “Correlation Matrix Heatmap”

# %% [markdown]
# # Program 12: Density Plot

# %%
d <- density(mtcars$mpg)
plot(d, main="Kernel Density of MPG")
polygon(d, col="red", border="blue")
# Out:
# Plot with title “Kernel Density of MPG”

# %% [markdown]
# # Program 5: R Line Plot (Base R)

# %%
set.seed(42)
x <- runif(50)
y <- x + rnorm(50, 0, 0.1)
plot(x, y, pch = 19, col = 'darkred', main = 'Scatter Plot')
# Out:
# Plot with title “Scatter Plot”

# %% [markdown]
# # Program 6: R Bar Chart (ggplot2)

# %%
# Program 4: Pie Chart

# %% [markdown]
# # Program 7: R Scatter Plot

# %%
slices <- c(45, 30, 15, 10)
lbls <- c('Python', 'Java', 'C++', 'Ruby')
pie(slices, labels = lbls, main = 'Pie Chart', col = terrain.colors(4))
# Out:
# Plot with title “Pie Chart”

# %% [markdown]
# # Program 8: R Pie Chart

# %%
slices <- c(45, 30, 15, 10)
lbls <- c("Python", "Java", "C++", "Ruby")
pie(slices, labels = lbls, main = "Pie Chart (R)", col = rainbow(length(lbls)))
# Out:
# Plot with title “Pie Chart (R)”
